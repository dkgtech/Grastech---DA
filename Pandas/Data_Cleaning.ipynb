# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading CSV file

# %%
df = pd.read_csv('/Users/dipeshgupta/Downloads/orders.csv')
df
# Out:
#         order_id           order_time  customer_id       city     locality  \
# 0       48110883  2025-07-16 14:27:04      5556469    Chennai        Adyar
# 1       86979781  2024-12-23 04:59:09      9790755  Hyderabad     Begumpet
# 2       17194718  2024-03-29 11:11:45      4853047    Kolkata        Garia
# 3       51824395  2024-07-02 17:51:06      1025320    Chennai        Adyar
# 4       84872995  2024-08-22 09:55:37      1871995     Jaipur   Mansarovar
# ...          ...                  ...          ...        ...          ...
# 299995  51959980  2024-09-16 06:23:05      6162027  Ahmedabad    Vastrapur
# 299996  70042051  2025-07-09 19:08:03      1777806     Mumbai        Powai
# 299997  14359742  2024-04-18 04:09:30      4413474     Mumbai  Lower Parel
# 299998  37596888  2024-05-19 17:14:53      6729429     Mumbai        Dadar
# 299999  12420352  2024-11-14 11:51:06      2928347      Delhi   Karol Bagh
#
# ...

# %% [markdown]
# # Check Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 42 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              300000 non-null  int64
#  1   order_time            300000 non-null  object
#  2   customer_id           300000 non-null  int64
#  3   city                  300000 non-null  object
#  4   locality              300000 non-null  object
#  5   warehouse_id          300000 non-null  object
#  6   delivery_partner_id   300000 non-null  object
#  7   product_id            300000 non-null  object
#  8   product_name          300000 non-null  object
#  9   category              300000 non-null  object
#  10  brand                 300000 non-null  object
#  11  quantity              300000 non-null  int64
#  12  unit_price            300000 non-null  float64
#  13  item_discount         300000 non-null  float64
# ...

# %% [markdown]
# # Check count, mean, etc...

# %%
df.describe()
# Out:
#            order_id   customer_id      quantity     unit_price  item_discount  \
# count  3.000000e+05  3.000000e+05  300000.00000  300000.000000  300000.000000
# mean   5.495757e+07  5.499781e+06       1.87742      27.419537       1.371637
# std    2.597714e+07  2.596435e+06       1.05352      15.529230       3.165682
# min    1.000058e+07  1.000004e+06       1.00000       7.200000       0.000000
# 25%    3.248284e+07  3.251893e+06       1.00000      16.580000       0.000000
# 50%    5.495957e+07  5.507775e+06       2.00000      23.770000       0.000000
# 75%    7.740714e+07  7.747448e+06       3.00000      34.060000       0.000000
# max    9.999980e+07  9.999983e+06       4.00000     256.360000      76.380000
#
#           item_total          taxes            tip  surge_multiplier  \
# count  300000.000000  300000.000000  300000.000000     300000.000000
# mean       48.892746       1.955656       3.945547          1.041779
# ...

# %% [markdown]
# # How to round

# %%
df.describe().round()
# Out:
#          order_id  customer_id  quantity  unit_price  item_discount  \
# count    300000.0     300000.0  300000.0    300000.0       300000.0
# mean   54957569.0    5499781.0       2.0        27.0            1.0
# std    25977140.0    2596435.0       1.0        16.0            3.0
# min    10000580.0    1000004.0       1.0         7.0            0.0
# 25%    32482842.0    3251893.0       1.0        17.0            0.0
# 50%    54959570.0    5507775.0       2.0        24.0            0.0
# 75%    77407143.0    7747448.0       3.0        34.0            0.0
# max    99999798.0    9999983.0       4.0       256.0           76.0
#
#        item_total     taxes       tip  surge_multiplier  row_grand_total  ...  \
# count    300000.0  300000.0  300000.0          300000.0         300000.0  ...
# mean         49.0       2.0       4.0               1.0             57.0  ...
# std          42.0       2.0      10.0               0.0             48.0  ...
# ...

# %% [markdown]
# # Check Null Values

# %%
df.isnull()
# Out:
#         order_id  order_time  customer_id   city  locality  warehouse_id  \
# 0          False       False        False  False     False         False
# 1          False       False        False  False     False         False
# 2          False       False        False  False     False         False
# 3          False       False        False  False     False         False
# 4          False       False        False  False     False         False
# ...          ...         ...          ...    ...       ...           ...
# 299995     False       False        False  False     False         False
# 299996     False       False        False  False     False         False
# 299997     False       False        False  False     False         False
# 299998     False       False        False  False     False         False
# 299999     False       False        False  False     False         False
#
#         delivery_partner_id  product_id  product_name  category  ...  \
# ...

# %% [markdown]
# # Sum of Null Values

# %%
df.isnull().sum()
# Out:
# order_id                     0
# order_time                   0
# customer_id                  0
# city                         0
# locality                     0
# warehouse_id                 0
# delivery_partner_id          0
# product_id                   0
# product_name                 0
# category                     0
# brand                        0
# quantity                     0
# unit_price                   0
# item_discount                0
# item_total                   0
# taxes                        0
# tip                          0
# surge_multiplier             0
# row_grand_total              0
# delivery_distance_km         0
# delivery_eta_min             0
# delivery_time_min         7362
# delivered_on_time         7362
# cancel_flag                  0
# return_flag                  0
# refund_amount                0
# rating                  164424
# payment_method               0
# coupon_code             225018
# platform                     0
# ...

# %% [markdown]
# # Check count of rows & columns

# %%
df.shape
# Out:
# (300000, 42)

# %% [markdown]
# # Sum of rows & columns

# %%
df.isnull().sum()/len(df)*100
# Out:
# order_id                 0.000
# order_time               0.000
# customer_id              0.000
# city                     0.000
# locality                 0.000
# warehouse_id             0.000
# delivery_partner_id      0.000
# product_id               0.000
# product_name             0.000
# category                 0.000
# brand                    0.000
# quantity                 0.000
# unit_price               0.000
# item_discount            0.000
# item_total               0.000
# taxes                    0.000
# tip                      0.000
# surge_multiplier         0.000
# row_grand_total          0.000
# delivery_distance_km     0.000
# delivery_eta_min         0.000
# delivery_time_min        2.454
# delivered_on_time        2.454
# cancel_flag              0.000
# return_flag              0.000
# refund_amount            0.000
# rating                  54.808
# payment_method           0.000
# coupon_code             75.006
# platform                 0.000
# ...

# %%
df.dropna().shape
# Out:
# (33080, 42)

# %%
df[df.duplicated()].shape
# Out:
# (0, 42)

# %% [markdown]
# # Check Duplicate Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_time, customer_id, city, locality, warehouse_id, delivery_partner_id, product_id, product_name, category, brand, quantity, unit_price, item_discount, item_total, taxes, tip, surge_multiplier, row_grand_total, delivery_distance_km, delivery_eta_min, delivery_time_min, delivered_on_time, cancel_flag, return_flag, refund_amount, rating, payment_method, coupon_code, platform, app_version, session_id, acquisition_channel, is_prime_member, weather, basket_size_est, latitude, longitude, hour_of_day, day_of_week, month, is_weekend]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# # Check count of particular column

# %%
df['customer_id'].value_counts().head()
# Out:
# customer_id
# 3691553    3
# 2488923    3
# 6699931    3
# 7165963    3
# 4237162    3
# Name: count, dtype: int64

# %%
df[df['customer_id'] == 3691553]
# Out:
#         order_id           order_time  customer_id     city       locality  \
# 48147   73355699  2025-03-29 10:33:39      3691553   Jaipur       C Scheme
# 113956  78272103  2024-08-11 05:50:08      3691553   Jaipur  Malviya Nagar
# 165850  46136348  2024-09-16 20:47:30      3691553  Chennai          Adyar
#
#        warehouse_id delivery_partner_id product_id          product_name  \
# 48147        WH-009            DP-04134    P000615  Local Brand Dog Food
# 113956       WH-028            DP-00353    P000195         Tata Biscuits
# 165850       WH-054            DP-04899    P000508          Nestle Sugar
#
#                  category  ... acquisition_channel  is_prime_member  \
# 48147            Pet Care  ...             Organic                1
# 113956  Snacks & Munchies  ...             Display                0
# 165850            Staples  ...             Organic                0
#
#            weather  basket_size_est   latitude  longitude  hour_of_day  \
# ...
