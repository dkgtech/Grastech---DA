# %% [markdown]
# # Output in Python

# %% [markdown]
# # Values
#     - Numerical value without decimal ex- 10,5,-20
#     - Numerical value with decimal ex- 10.22,14.28, -29.22
#     - Non Numerical value ex- 'dipesh','da'

# %% [markdown]
# **Print Single Variables**

# %%
print(10)
# Out:
# 10
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
print("dipesh")
# Out:
# dipesh

# %%
print("dipesh","gupta",sep=":")
# Out:
# dipesh:gupta

# %%
a=10
a
# Out:
# 10

# %% [markdown]
# **Print Multiple Variables**

# %%
a=10
b=20
print(a,b)
# Out:
# 10 20

# %%
a,b,c = 30,40,50
print(a,b,c)
# Out:
# 30 40 50

# %% [markdown]
# **Print(combination of both values & variables)**

# %%
print(12,a)
# Out:
# 12 30

# %%
print("the value of a:",a)
# Out:
# the value of a: 30

# %%
print("The value of a:",a," The value of b:",b)
# Out:
# The value of a: 30  The value of b: 40
