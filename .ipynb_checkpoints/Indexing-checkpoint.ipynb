# %%
name = "Dipesh Kumar Gupta"

# %%
name = "Dipesh Kumar Gupta"

# %%
name[0]
# Out:
# 'D'

# %%
name[1]
# Out:
# 'i'

# %%
name[2]
# Out:
# 'p'

# %%
name[3]
# Out:
# 'e'

# %%
name[4]
# Out:
# 's'

# %%
name[5]
# Out:
# 'h'

# %%
name[6]
# Out:
# ' '

# %% [markdown]
# # Slicing
