# %% [markdown]
# # Dictonary

# %%
course = {
    'title' : 'Python',
    'duration' : '2 Months',
    'fee' : 'Rs. 10,000'
}
print(course)
# Out:
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 10,000'}

# %%
print(course['duration'])
# Out:
# 2 Months

# %%
course['title']
# Out:
# 'Python'

# %%
course.get('fee')
# Out:
# 'Rs. 10,000'

# %%
course['fee'] = 'Rs. 20000'

# %%
course
# Out:
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000'}

# %%
for item in course:
    print(course)
# Out:
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000'}
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000'}
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000'}

# %%
for i in course:
    print(i,course[i])
# Out:
# title Python
# duration 2 Months
# fee Rs. 20000

# %%
for key, value in course.items():
    print(key, value)
# Out:
# title Python
# duration 2 Months
# fee Rs. 20000

# %% [markdown]
# # Methods

# %% [markdown]
# # Length

# %%
print(len(course))
# Out:
# 3

# %%
course['id'] = '001'

# %%
course
# Out:
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000', 'id': '001'}

# %% [markdown]
# # POP

# %%
course.pop('id')
# Out:
# '001'

# %%
course
# Out:
# {'title': 'Python', 'duration': '2 Months', 'fee': 'Rs. 20000'}

# %% [markdown]
# # POP Item

# %%
course.popitem()
# Out:
# ('fee', 'Rs. 20000')

# %%
course
# Out:
# {'title': 'Python', 'duration': '2 Months'}

# %%
del course['duration']

# %%
course
# Out:
# {'title': 'Python'}

# %% [markdown]
# # Copy

# %%
course_copy = course.copy()

# %%
course_copy
# Out:
# {'title': 'Python'}

# %%
c = {
    'Python': {'id':'001','duration':'6 Months','fee':20000},
    'Android':{'id':'002','duration':'3 Months','fee':18000},
    'Java':{'id':'003','duration':'4 Months','fee':25000}
}

# %%
c
# Out:
# {'Python': {'id': '001', 'duration': '6 Months', 'fee': 20000},
#  'Android': {'id': '002', 'duration': '3 Months', 'fee': 18000},
#  'Java': {'id': '003', 'duration': '4 Months', 'fee': 25000}}

# %%
print(c)
# Out:
# {'Python': {'id': '001', 'duration': '6 Months', 'fee': 20000}, 'Android': {'id': '002', 'duration': '3 Months', 'fee': 18000}, 'Java': {'id': '003', 'duration': '4 Months', 'fee': 25000}}

# %%
c['Python']
# Out:
# {'id': '001', 'duration': '6 Months', 'fee': 20000}

# %%
c['Python']['fee']
# Out:
# 20000

# %%
squared_num = {x:x**2 for x in range(1,11)}

# %%
squared_num
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# # Clear

# %%
squared_num.clear()

# %%
squared_num
# Out:
# {}

# %% [markdown]
# # fromKeys

# %%
tea = ['Masala','Ginger','Green']
default_value = 'Delicious'

new_dict = dict.fromkeys(tea,default_value)

# %%
new_dict
# Out:
# {'Masala': 'Delicious', 'Ginger': 'Delicious', 'Green': 'Delicious'}

# %%
new_dict = dict.fromkeys(tea,'Zesty')

# %%
new_dict
# Out:
# {'Masala': 'Zesty', 'Ginger': 'Zesty', 'Green': 'Zesty'}

# %% [markdown]
# # Items

# %%
new_dict.items()
# Out:
# dict_items([('Masala', 'Zesty'), ('Ginger', 'Zesty'), ('Green', 'Zesty')])

# %% [markdown]
# # Keys

# %%
new_dict.keys()
# Out:
# dict_keys(['Masala', 'Ginger', 'Green'])

# %% [markdown]
# # Values

# %%
new_dict.values()
# Out:
# dict_values(['Zesty', 'Zesty', 'Zesty'])

# %%
new_dict
# Out:
# {'Masala': 'Zesty', 'Ginger': 'Zesty', 'Green': 'Zesty'}

# %%
new_dict.setdefault('Lemon')

# %%
new_dict
# Out:
# {'Masala': 'Zesty', 'Ginger': 'Zesty', 'Green': 'Zesty', 'Lemon': None}

# %%
new_dict['Lemon'] = 'Delicious'

# %%
new_dict
# Out:
# {'Masala': 'Zesty', 'Ginger': 'Zesty', 'Green': 'Zesty', 'Lemon': 'Delicious'}

# %% [markdown]
# # Set Default

# %%
new_dict.setdefault('Black Tea','Mild')
# Out:
# 'Mild'

# %%
new_dict
# Out:
# {'Masala': 'Zesty',
#  'Ginger': 'Zesty',
#  'Green': 'Zesty',
#  'Lemon': 'Delicious',
#  'Black Tea': 'Mild'}

# %% [markdown]
# # Deafult

# %%
new_dict.update({'Masala' : 'Spicy'})

# %%
new_dict
# Out:
# {'Masala': 'Spicy',
#  'Ginger': 'Zesty',
#  'Green': 'Zesty',
#  'Lemon': 'Delicious',
#  'Black Tea': 'Mild'}

# %%
new_dict.update({'new_key':'new_value'})

# %%
new_dict
# Out:
# {'Masala': 'Spicy',
#  'Ginger': 'Zesty',
#  'Green': 'Zesty',
#  'Lemon': 'Delicious',
#  'Black Tea': 'Mild',
#  'new_key': 'new_value'}

# %%
for i in new_dict:
    print(i)
# Out:
# Masala
# Ginger
# Green
# Lemon
# Black Tea
# new_key

# %%
for i,j in new_dict.items():
    print(i,': '+j)
# Out:
# Masala : Spicy
# Ginger : Zesty
# Green : Zesty
# Lemon : Delicious
# Black Tea : Mild
# new_key : new_value
