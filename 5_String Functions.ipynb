# %% [markdown]
# # String Functions

# %%
name = 'Dipesh'

# %%
name.upper()
# Out:
# 'DIPESH'

# %%
name.lower()
# Out:
# 'dipesh'

# %%
name.capitalize()
# Out:
# 'Dipesh'

# %%
name.title()
# Out:
# 'Dipesh'

# %%
data = 'My name is Dipesh Kumar Gupta'

# %%
data.lower()
# Out:
# 'my name is dipesh kumar gupta'

# %%
data.casefold()
# Out:
# 'my name is dipesh kumar gupta'

# %%
data.upper()
# Out:
# 'MY NAME IS DIPESH KUMAR GUPTA'

# %%
data.center(100,"*")
# Out:
# '***********************************My name is Dipesh Kumar Gupta************************************'

# %%
data.count('a')
# Out:
# 3

# %%
data
# Out:
# 'My name is Dipesh Kumar Gupta'

# %%
data.replace('Dipesh','Sachin')
# Out:
# 'My name is Sachin Kumar Gupta'

# %%
data.find('D')
# Out:
# 11

# %%
data[data.find('D'):]
# Out:
# 'Dipesh Kumar Gupta'

# %%
data.find('a')
# Out:
# 4

# %%
data.find('a',5)
# Out:
# 21

# %%
data[data.find('a'):22]
# Out:
# 'ame is Dipesh Kuma'

# %%
car = 'Maruti'
price = 25000000
year = 2024
msg = 'I have a {} car, having price of Rs. {} of model {}.'.format(car,price,year)
print(msg)
# Out:
# I have a Maruti car, having price of Rs. 25000000 of model 2024.

# %%
# FString

c = 'Maruti'
p = 25000000
y = 2024
msg = f'I have a {c} car, having price of Rs. {p} of model {y}.'
print(msg)
# Out:
# I have a Maruti car, having price of Rs. 25000000 of model 2024.

# %%
data.isalnum()
# Out:
# False

# %%
data.isalpha()
# Out:
# False

# %%
data.isdigit()
# Out:
# False

# %%
data.isascii()
# Out:
# True

# %%
import emoji
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 import emoji
#
# ModuleNotFoundError: No module named 'emoji'

# %%
# pip install emoji

# %%
import emoji

# %%
emoji.EMOJI_DATA
# Out:
# {'🥇': {'en': ':1st_place_medal:', 'status': 2, 'E': 3},
#  '🥈': {'en': ':2nd_place_medal:', 'status': 2, 'E': 3},
#  '🥉': {'en': ':3rd_place_medal:', 'status': 2, 'E': 3},
#  '🆎': {'en': ':AB_button_(blood_type):',
#   'status': 2,
#   'E': 0.6,
#   'alias': [':ab:', ':ab_button_blood_type:']},
#  '🏧': {'en': ':ATM_sign:',
#   'status': 2,
#   'E': 0.6,
#   'alias': [':atm:', ':atm_sign:']},
#  '🅰️': {'en': ':A_button_(blood_type):',
#   'status': 2,
#   'E': 0.6,
#   'alias': [':a:', ':a_button_blood_type:'],
#   'variant': True},
#  '🅰': {'en': ':A_button_(blood_type):',
#   'status': 4,
#   'E': 0.6,
#   'alias': [':a:', ':a_button_blood_type:'],
#   'variant': True},
#  '🇦🇫': {'en': ':Afghanistan:',
#   'status': 2,
#   'E': 2,
#   'alias': [':flag_for_Afghanistan:', ':afghanistan:']},
#  '🇦🇱': {'en': ':Albania:',
#   'status': 2,
#   'E': 2,
#   'alias': [':flag_for_Albania:', ':albania:']},
#  '🇩🇿': {'en': ':Algeria:',
#   'status': 2,
#   'E': 2,
# ...

# %%
# join
data = 'My name is Dipesh Kumar Gupta'
msg = '  '

# %%
msg.join(data)
# Out:
# 'M  y     n  a  m  e     i  s     D  i  p  e  s  h     K  u  m  a  r     G  u  p  t  a'

# %%
data = "       Hello how are you?                 "

# %%
data.lstrip()
# Out:
# 'Hello how are you?                 '

# %%
data.rstrip()
# Out:
# '       Hello how are you?'

# %%
data.strip()
# Out:
# 'Hello how are you?'

# %%
data.partition('o')
# Out:
# ('       Hell', 'o', ' how are you?                 ')

# %%
new_data = data.strip()

# %%
new_data.split(' ')
# Out:
# ['Hello', 'how', 'are', 'you?']

# %%
new_data.endswith('?')
# Out:
# True

# %%
new_data.startswith('Hello')
# Out:
# True

# %%
a = 'Mr. Dipesh Kumar Gupta'

# %%
a.removeprefix('Mr. ')
# Out:
# 'Dipesh Kumar Gupta'

# %%
a = 'Mr. Dipesh Kumar Gupta, Mumbai Wale'

# %%
a.removesuffix(', Mumbai Wale')
# Out:
# 'Mr. Dipesh Kumar Gupta'

# %%
a.removesuffix(', Mumbai Wale').removeprefix('Mr. ')
# Out:
# 'Dipesh Kumar Gupta'

# %%
# swapcase

# %%
a.swapcase()
# Out:
# 'mR. dIPESH kUMAR gUPTA, mUMBAI wALE'

# %%
a = 'Dipesh'

# %%
a.zfill(10)
# Out:
# '0000Dipesh'

# %%
a.ljust(10,'0')
# Out:
# 'Dipesh0000'
