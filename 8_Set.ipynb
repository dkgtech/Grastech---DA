# %% [markdown]
# # Set

# %%
# Unordered collection of unique data and each value must be unique

# %%
data = {2,3,4,5,6,7,8,9,2,2,4,4,5,5,7,7}

# %%
data
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
students = ['dipesh','sachin','deepak','mahesh','sachin','deepak','mahesh','rahul']

# %%
set(students)
# Out:
# {'deepak', 'dipesh', 'mahesh', 'rahul', 'sachin'}

# %%
# set can contain multiple data types, immutable

# %% [markdown]
# # Set Methods

# %%
a = {12,13,14,44,456,789}
b = {10,11,12,14,345,678}

# %% [markdown]
# # Intersection

# %%
a.intersection(b)
# Out:
# {12, 14}

# %%
a & b
# Out:
# {12, 14}

# %% [markdown]
# # Union

# %%
a.union(b)
# Out:
# {10, 11, 12, 13, 14, 44, 345, 456, 678, 789}

# %%
a | b
# Out:
# {10, 11, 12, 13, 14, 44, 345, 456, 678, 789}

# %% [markdown]
# # Difference

# %%
a.difference(b)
# Out:
# {13, 44, 456, 789}

# %%
a - b
# Out:
# {13, 44, 456, 789}

# %%
b.difference(a)
# Out:
# {10, 11, 345, 678}

# %%
b - a
# Out:
# {10, 11, 345, 678}

# %% [markdown]
# # Symmetric Difference

# %%
a
# Out:
# {12, 13, 14, 44, 456, 789}

# %%
b
# Out:
# {10, 11, 12, 14, 345, 678}

# %%
a.symmetric_difference(b)
# Out:
# {10, 11, 13, 44, 345, 456, 678, 789}
